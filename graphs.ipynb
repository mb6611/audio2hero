# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
losses = np.load("losses.npy")

# %%
average_losses = [np.mean(epoch) for epoch in losses]

# %%
plt.title("Average Cross-Entropy Loss Per Epoch (40 Guitar Hero 5 songs)")
plt.xlabel("Epoch")
plt.ylabel("Average Cross-Entropy Loss")
plt.ylim(0,1.5)
plt.plot(list(range(len(average_losses))), average_losses)
plt.show()

# %%
losses2 = np.load("losses2.npy")
average_losses2 = [np.mean(epoch) for epoch in losses2]

# %%
plt.title("Average Cross-Entropy Loss Per Epoch (One Guitar Hero 5 song)")
plt.xlabel("Epoch")
plt.ylabel("Average Cross-Entropy Loss")
plt.ylim(0,1.5)
plt.plot(list(range(len(average_losses2))), average_losses2)
plt.show()

# %%
losses3 = np.load("losses3.npy")
average_losses3 = [np.mean(epoch) for epoch in losses3]

# %%
plt.title("Average Cross-Entropy Loss Per Epoch (40 Guitar Hero 5 songs)")
plt.xlabel("Epoch")
plt.ylabel("Average Cross-Entropy Loss")
plt.ylim(0,1.5)
plt.plot(list(range(len(average_losses3))), average_losses3)
plt.show()

# %%
accuracies3 = np.load("accuracies3.npy")
average_accuracies3 = [np.mean(epoch) for epoch in accuracies3]

# %%
plt.title("Average Accuracy Per Epoch (40 Guitar Hero 5 songs)")
plt.xlabel("Epoch")
plt.ylabel("Average Accuracy")
plt.ylim(0,1)
plt.plot(list(range(len(average_accuracies3))), average_accuracies3)
plt.show()

# %%
accuracies5 = np.load("accuracies5.npy")
average_accuracies5 = [np.mean(epoch) for epoch in accuracies5]

# %%
plt.title("Average Accuracy Per Epoch (40 Guitar Hero 5 songs)")
plt.xlabel("Epoch")
plt.ylabel("Average Accuracy")
plt.ylim(0,1)
plt.plot(list(range(len(average_accuracies5))), average_accuracies5)
plt.show()

# %%
losses5 = np.load("losses5.npy")
average_losses5 = [np.mean(epoch) for epoch in losses5]

# %%
plt.title("Average Loss Per Epoch (40 Guitar Hero 5 songs)")
plt.xlabel("Epoch")
plt.ylabel("Average Loss")
plt.ylim(0,1.5)
plt.plot(list(range(len(average_losses5))), average_losses5)
plt.show()

# %%
total_average_losses_40 = np.concatenate((average_losses3, average_losses5))
plt.title("Average Loss Per Epoch (40 Guitar Hero 5 songs, 300+ Epochs)")
plt.xlabel("Epoch")
plt.ylabel("Average Loss")
plt.ylim(0,1.5)
plt.plot(list(range(len(total_average_losses_40))), total_average_losses_40)

x = list(range(len(total_average_losses_40)))
y = total_average_losses_40
coefficients = np.polyfit(x, y, 1)
plt.plot(x, np.poly1d(coefficients)(x), label=f'Line of Best Fit (Slope={coefficients[0]:.4f})')
plt.legend()

plt.show()

# %%
total_average_accuracies_40 = np.concatenate((average_accuracies3, average_accuracies5))
plt.title("Average Accuracies Per Epoch (40 Guitar Hero 5 songs, 300+ Epochs)")
plt.xlabel("Epoch")
plt.ylabel("Average Accuracies")
plt.ylim(0,1)
plt.plot(list(range(len(total_average_accuracies_40))), total_average_accuracies_40)

x = list(range(len(total_average_accuracies_40)))
y = total_average_accuracies_40
coefficients = np.polyfit(x, y, 1)
plt.plot(x, np.poly1d(coefficients)(x), label=f'Line of Best Fit (Slope={coefficients[0]:.4f})')
plt.legend()
#plt.plot(np.unique(x), np.poly1d(np.polyfit(x, y, 1))(np.unique(x)))
plt.show()

# %%
ada_losses = np.load("losses_adafactor.npy")
ada_losses = [np.mean(epoch) for epoch in ada_losses]

result = ada_losses[:20]

#total_average_losses_ = np.concatenate((average_losses3, average_losses5))
plt.title("Average Loss Per Epoch (40 Guitar Hero 5 songs, 300+ Epochs)")
plt.xlabel("Epoch")
plt.ylabel("Average Loss")
#plt.ylim(0,1.5)
plt.plot(list(range(len(result))), ada_losses)

#x = list(range(len(ada_losses)))
#y = ada_losses
#coefficients = np.polyfit(x, y, 1)
#plt.plot(x, np.poly1d(coefficients)(x), label=f'Line of Best Fit (Slope={coefficients[0]:.4f})')
#plt.legend()

plt.show()

# %%
ada_accuracies = np.load("accuracies_adafactor.npy")
ada_accuracies = [np.mean(epoch) for epoch in ada_accuracies]

#total_average_losses_ = np.concatenate((average_losses3, average_losses5))
plt.title("Average Accuracy Per Epoch (40 Guitar Hero 5 songs, 300+ Epochs)")
plt.xlabel("Epoch")
plt.ylabel("Average Accuracy")
#plt.ylim(0,1.5)
plt.plot(list(range(len(ada_accuracies))), ada_accuracies)

#x = list(range(len(ada_losses)))
#y = ada_losses
#coefficients = np.polyfit(x, y, 1)
#plt.plot(x, np.poly1d(coefficients)(x), label=f'Line of Best Fit (Slope={coefficients[0]:.4f})')
#plt.legend()

plt.show()
