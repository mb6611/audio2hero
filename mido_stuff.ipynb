# %%
import mido

# %%
gh = mido.MidiFile('./processed/midi/Mountain - Mississippi Queen.mid')

# %%
# Out:
# MidiFile(type=1, ticks_per_beat=480, tracks=[
#   MidiTrack([
#     MetaMessage('set_tempo', tempo=428000, time=0),
#     MetaMessage('time_signature', numerator=4, denominator=4, clocks_per_click=24, notated_32nd_notes_per_beat=8, time=0),
#     MetaMessage('set_tempo', tempo=429000, time=480),
#     MetaMessage('set_tempo', tempo=428000, time=480),
#     MetaMessage('set_tempo', tempo=429000, time=480),
#     MetaMessage('set_tempo', tempo=427000, time=480),
#     MetaMessage('set_tempo', tempo=428000, time=480),
#     MetaMessage('set_tempo', tempo=425000, time=480),
#     MetaMessage('set_tempo', tempo=428000, time=480),
#     MetaMessage('set_tempo', tempo=432000, time=480),
#     MetaMessage('set_tempo', tempo=428000, time=480),
#     MetaMessage('set_tempo', tempo=430000, time=480),
#     MetaMessage('set_tempo', tempo=426000, time=960),
#     MetaMessage('set_tempo', tempo=423000, time=480),
#     MetaMessage('set_tempo', tempo=425000, time=480),
# ...

# %%
gh.tracks[0]=gh.tracks[0][0:2]

# %%
gh
# Out:
# MidiFile(type=1, ticks_per_beat=480, tracks=[
#   MidiTrack([
#     MetaMessage('set_tempo', tempo=428000, time=0),
#     MetaMessage('time_signature', numerator=4, denominator=4, clocks_per_click=24, notated_32nd_notes_per_beat=8, time=0)]),
#   MidiTrack([
#     MetaMessage('track_name', name='PART GUITAR', time=0),
#     Message('note_on', channel=0, note=72, velocity=100, time=5040),
#     Message('note_on', channel=0, note=78, velocity=100, time=0),
#     Message('note_on', channel=0, note=72, velocity=0, time=1),
#     Message('note_on', channel=0, note=78, velocity=0, time=0),
#     Message('note_on', channel=0, note=73, velocity=100, time=239),
#     Message('note_on', channel=0, note=78, velocity=100, time=0),
#     Message('note_on', channel=0, note=73, velocity=0, time=1),
#     Message('note_on', channel=0, note=78, velocity=0, time=0),
#     Message('note_on', channel=0, note=75, velocity=100, time=239),
# ...

# %%
gh.save('gh_mountain_single_tempo.mid')
